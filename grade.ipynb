# %% [markdown]
# <a href="https://colab.research.google.com/github/samyzaf/notebooks/blob/main/grade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir=rtl>
# <h1><strong>משוב לפרוייקט בפונקציות הרמוניות</strong></h1>
# <ul>
# <li>עד שהתקלה בערכת המודל (Moodle) תטופל, תוכלו לגשת לקובץ המשוב grade.py
#   באמצעות הטופס הבא.</li>
# </ul>
# </div>

# %% [markdown]
# <div dir=rtl>
# <h2><strong>טופס פרטי סטודנט</strong></h2>
# <ul>
# <li>לשמירת פרטיות ובטיחות, יש למלא את כל ארבעות השדות הבאים בכדי לקבל גישה לקובצי המשוב.</li>
# <li>יש לדייק לחלוטין בפרטים, אחרת הקישור שיווצר לא יעבוד!</li>
# <li>לאחר מילוי הפרטים יש ללחוץ על כפתור ההפעלה &#9658; בכדי לקבל קישור לתיקיית המשוב.</li>
# <li>לבעיות נא לפנות ל: samyz@technion.ac.il</li>
# </ul>
# </div>

# %%
# @title **Student Form** {"form-width":"50%"}
Name = 'הכנס כאן שם תקני מלא בעברית' # @param {type:"string"}
Id = 'הקלד כאן את מספר הזהות' # @param {type:"string"}
#Sid = 'הקלד כאן את מספר הסטודנט בפרוייקט' # @param {type:"string"}
Email = 'הקלד את הדואר האלקטרוני' # @param {type:"string"}
Grade = 'הקלד את הציון שקבלת בפרוייקט' # @param {type:"string"}

# %pip install -q -r https://samyzaf.com/feedback.pkg
from gctools import *
ColabExec("feedback")
