# %% [markdown]
# <a href="https://colab.research.google.com/github/samyzaf/notebooks/blob/main/harmonic_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation
# * Run the following cell to install the **cfclon** package
#   and harmonic matrices database needed for the exercise.

# %%
# %pip install https://samyzaf.com/cfclon-33.zip
from cfclon import *
plt.rcParams['figure.dpi'] = 90
reg.log.state = "disabled"
dbname = "https://samyzaf.com/aleph128a.db"
load_db(dbname)
# Out:
# Collecting https://samyzaf.com/cfclon-33.zip
#   Downloading https://samyzaf.com/cfclon-33.zip (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from cfclon==33) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from cfclon==33) (3.7.1)
# Collecting ezsettings (from cfclon==33)
#   Downloading ezsettings-1.1.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ezprogbar (from cfclon==33)
#   Downloading ezprogbar-1.21.tar.gz (1.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->cfclon==33) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->cfclon==33) (1.16.0)
# Building wheels for collected packages: cfclon, ezprogbar, ezsettings
#   Building wheel for cfclon (setup.py) ... done
#   Created wheel for cfclon: filename=cfclon-33-py3-none-any.whl size=15976 sha256=337bca827cdc88b3d9783aa2670ba3dbef3d2bad0e1e0c46f5491a62700e80b2
#   Stored in directory: /root/.cache/pip/wheels/4f/10/9e/c1ae512b46f8519f72b3e6bc99637075be800f1eb3a63b4a80
#   Building wheel for ezprogbar (setup.py) ... done
#   Created wheel for ezprogbar: filename=ezprogbar-1.21-py3-none-any.whl size=2392 sha256=14f2bc8f809223bed9376333d331bffd6e475160c251363cef8a6384e02ffaba
#   Stored in directory: /root/.cache/pip/wheels/b2/de/43/b95f1bccfc3910a2de45fe570c16b729708c03139833060c2d
#   Building wheel for ezsettings (setup.py) ... done
#   Created wheel for ezsettings: filename=ezsettings-1.1-py3-none-any.whl size=3220 sha256=30e916ba7fb5e6d0e2ff991aa7ebf1637aa80fa3f986fae84f4a59af4505694c
#   Stored in directory: /root/.cache/pip/wheels/94/01/68/1fd6affeada96b8e86115c6c5eed029b3ab06c38f5e7a6af68
# Successfully built cfclon ezprogbar ezsettings
# Installing collected packages: ezsettings, ezprogbar, cfclon
# Successfully installed cfclon-33 ezprogbar-1.21 ezsettings-1.1

# %%
url = "https://samyzaf.com/cfproj/aleph2.svg"
aleph = read_polygon(url, tag="aleph")
cage = read_polygon(url, tag="cage")
draw_cage(cage)
draw_curve(aleph, facecolor="aliceblue", fill=True)
show_plot()

# %%
dbname = "https://samyzaf.com/aleph2a.db"
load_db(dbname)

# %%
url = "https://samyzaf.com/cfproj/aleph3.svg"
aleph = read_polygon(url, tag="aleph")
cage2 = read_polygon(url, tag="cage2")
draw_cage(cage2)
coords_list = harmonic_coordinates(aleph)
cloned_points = clone(coords_list, cage2)
draw_curve(cloned_points, fill=True, linewidth=1, facecolor="cyan")
show_plot()

# %% [markdown]
# Lets see how it looks using Mean Value coordinates:

# %%
mean_coords = get_mean_value_coords_map(cage)
coords_list = mean_coords(aleph)
cloned_points = clone(coords_list, cage2)
draw_cage(cage2)
draw_curve(cloned_points, fill=True, linewidth=1, facecolor="cyan")
show_plot()

# %% [markdown]
# * This is almost identical to what we got using Harmonic Coordinates!
# * It shows that in many cases **Mean Value Coordinates** are OK to use. They are much cheaper computationaly and 100% precise (we have closed form formula for the in contrast to an approximate numeric computation for Harmonic Coordinates).
